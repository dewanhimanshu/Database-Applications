# %% [markdown]
# **Name of the Student:** Himanshu Dewan<br>
# **Roll number:**    21

# %%
# import required libraries
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
from sqlalchemy import create_engine
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### Use NorthWind Database for Q.1 to Q.17

# %%
# Set up connection with NorthWind Database
# %sql postgresql://postgres:himanshu@localhost/NorthWind
engine = create_engine('postgresql://postgres:himanshu@localhost/NorthWind')

# %% [markdown]
# 1. Which shippers do we have?( Hint: We have a table called Shippers. Return all the fields from all the shippers)

# %%
# %%sql
#     select * from shippers
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 6 rows affected.
# [(1, 'Speedy Express', '(503) 555-9831'),
#  (2, 'United Package', '(503) 555-3199'),
#  (3, 'Federal Shipping', '(503) 555-9931'),
#  (4, 'Alliance Shippers', '1-800-222-0451'),
#  (5, 'UPS', '1-800-782-7892'),
#  (6, 'DHL', '1-800-225-5345')]

# %% [markdown]
# 2. Write a SQL query to see first name, last name and hire date of all the employees with the title of **sales representative.**

# %%
# %%sql
#      select first_name , last_name , hire_date from employees where title = 'Sales Representative'
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 6 rows affected.
# [('Nancy', 'Davolio', datetime.date(1992, 5, 1)),
#  ('Janet', 'Leverling', datetime.date(1992, 4, 1)),
#  ('Margaret', 'Peacock', datetime.date(1993, 5, 3)),
#  ('Michael', 'Suyama', datetime.date(1993, 10, 17)),
#  ('Robert', 'King', datetime.date(1994, 1, 2)),
#  ('Anne', 'Dodsworth', datetime.date(1994, 11, 15))]

# %% [markdown]
# 3. Write a SQL query to extract first name, last name and hire date of only those employees that have the title of Sales Representative, and also are in the United States.

# %%
# %%sql
#      select first_name , last_name , hire_date from employees where title = 'Sales Representative' and country = 'USA'
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 3 rows affected.
# [('Nancy', 'Davolio', datetime.date(1992, 5, 1)),
#  ('Janet', 'Leverling', datetime.date(1992, 4, 1)),
#  ('Margaret', 'Peacock', datetime.date(1993, 5, 3))]

# %% [markdown]
# 4. Show all the orders placed by the Employee "Stevan Buchanan" whose employee id is 5.

# %%
# %%sql
#     select * from orders where employee_id = '5'
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 42 rows affected.
# [(10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France'),
#  (10254, 'CHOPS', 5, datetime.date(1996, 7, 11), datetime.date(1996, 8, 8), datetime.date(1996, 7, 23), 2, 22.98, 'Chop-suey Chinese', 'Hauptstr. 31', 'Bern', None, '3012', 'Switzerland'),
#  (10269, 'WHITC', 5, datetime.date(1996, 7, 31), datetime.date(1996, 8, 14), datetime.date(1996, 8, 9), 1, 4.56, 'White Clover Markets', '1029 - 12th Ave. S.', 'Seattle', 'WA', '98124', 'USA'),
#  (10297, 'BLONP', 5, datetime.date(1996, 9, 4), datetime.date(1996, 10, 16), datetime.date(1996, 9, 10), 2, 5.74, 'Blondel père et fils', '24, place Kléber', 'Strasbourg', None, '67000', 'France'),
#  (10320, 'WARTH', 5, datetime.date(1996, 10, 3), datetime.date(1996, 10, 17), datetime.date(1996, 10, 18), 3, 34.57, 'Wartian Herkku', 'Torikatu 38', 'Oulu', None, '90110', 'Finland'),
#  (10333, 'WARTH', 5, datetime.date(1996, 10, 18), datetime.date(1996, 11, 15), datetime.date(1996, 10, 25), 3, 0.59, 'Wartian Herkku', 'Torikatu 38', 'Oulu', None, '90110', 'Finland'),
#  (10358, 'LAMAI', 5, datetime.date(1996, 11, 20), datetime.date(1996, 12, 18), datetime.date(1996, 11, 27), 1, 19.64, "La maison d'Asie", '1 rue Alsace-Lorraine', 'Toulouse', None, '31000', 'France'),
#  (10359, 'SEVES', 5, datetime.date(1996, 11, 21), datetime.date(1996, 12, 19), datetime.date(1996, 11, 26), 3, 288.43, 'Seven Seas Imports', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'U
 'Rattlesnake Canyon Grocery', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA'),
#  (10812, 'REGGC', 5, datetime.date(1998, 1, 2), datetime.date(1998, 1, 30), datetime.date(1998, 1, 12), 1, 59.78, 'Reggiani Caseifici', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy'),
#  (10823, 'LILAS', 5, datetime.date(1998, 1, 9), datetime.date(1998, 2, 6), datetime.date(1998, 1, 13), 2, 163.97, 'LILA-Supermercado', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela'),
#  (10841, 'SUPRD', 5, datetime.date(1998, 1, 20), datetime.date(1998, 2, 17), datetime.date(1998, 1, 29), 2, 424.3, 'Suprêmes délices', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium'),
#  (10851, 'RICAR', 5, datetime.date(1998, 1, 26), datetime.date(1998, 2, 23), datetime.date(1998, 2, 2), 1, 160.55, 'Ricardo Adocicados', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil'),
#  (10866, 'BERGS', 5, datetime.date(1998, 2, 3), datetime.date(1998, 3, 3), datetime.date(1998, 2, 12), 1, 109.11, 'Berglunds snabbköp', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden'),
#  (10869, 'SEVES', 5, datetime.date(1998, 2, 4), datetime.date(1998, 3, 4), datetime.date(1998, 2, 9), 1, 143.28, 'Seven Seas Imports', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK'),
#  (10870, 'WOLZA', 5, datetime.date(1998, 2, 4), datetime.date(1998, 3, 4), datetime.date(1998, 2, 13), 3, 12.04, 'Wolski Zajazd', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland'),
#  (10872, 'GODOS', 5, datetime.date(1998, 2, 5), datetime.date(1998, 3, 5), datetime.date(1998, 2, 9), 2, 175.32, 'Godos Cocina Típica', 'C/ Romero, 33', 'Sevilla', None, '41101', 'Spain'),
#  (10874, 'GODOS', 5, datetime.date(1998, 2, 6), datetime.date(1998, 3, 6), datetime.date(1998, 2, 11), 2, 19.58, 'Godos Cocina Típica', 'C/ Romero, 33', 'Sevilla', None, '41101', 'Spain'),
#  (10899, 'LILAS', 5, datetime.date(1998, 2, 20), datetime.date(1998, 3, 20), datetime.date(1998, 2, 26), 3, 1.21, 'LILA-Supermercado', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela'),
#  (10922, 'HANAR', 5, datetime.date(1998, 3, 3), datetime.date(1998, 3, 31), datetime.date(1998, 3, 5), 3, 62.74, 'Hanari Carnes', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil'),
#  (10954, 'LINOD', 5, datetime.date(1998, 3, 17), datetime.date(1998, 4, 28), datetime.date(1998, 3, 20), 1, 27.91, 'LINO-Delicateses', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela'),
#  (11043, 'SPECD', 5, datetime.date(1998, 4, 22), datetime.date(1998, 5, 20), datetime.date(1998, 4, 29), 2, 8.8, 'Spécialités du monde', '25, rue Lauriston', 'Paris', None, '75016', 'France')]

# %% [markdown]
# 5. Show the SupplierID, ContactName and ContactTitle for those suppliers whose ContactTitle is not Marketing Manager. (Hint: Suppliers Table)

# %%
# %%sql
#      select supplier_id,contact_name,contact_title from suppliers where contact_title != 'Marketing Manager'
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 24 rows affected.
# [(1, 'Charlotte Cooper', 'Purchasing Manager'),
#  (2, 'Shelley Burke', 'Order Administrator'),
#  (3, 'Regina Murphy', 'Sales Representative'),
#  (5, 'Antonio del Valle Saavedra', 'Export Administrator'),
#  (6, 'Mayumi Ohno', 'Marketing Representative'),
#  (8, 'Peter Wilson', 'Sales Representative'),
#  (9, 'Lars Peterson', 'Sales Agent'),
#  (11, 'Petra Winkler', 'Sales Manager'),
#  (12, 'Martin Bein', 'International Marketing Mgr.'),
#  (13, 'Sven Petersen', 'Coordinator Foreign Markets'),
#  (14, 'Elio Rossi', 'Sales Representative'),
#  (16, 'Cheryl Saylor', 'Regional Account Rep.'),
#  (17, 'Michael Björn', 'Sales Representative'),
#  (18, 'Guylène Nodier', 'Sales Manager'),
#  (19, 'Robb Merchant', 'Wholesale Account Agent'),
#  (20, 'Chandra Leka', 'Owner'),
#  (21, 'Niels Petersen', 'Sales Manager'),
#  (22, 'Dirk Luchte', 'Accounting Manager'),
#  (23, 'Anne Heikkonen', 'Product Manager'),
#  (24, 'Wendy Mackenzie', 'Sales Representative'),
#  (26, 'Giovanni Giudici', 'Order Administrator'),
#  (27, 'Marie Delamare', 'Sales Manager'),
#  (28, 'Eliane Noz', 'Sales Representative'),
#  (29, 'Chantal Goulet', 'Accounting Manager')]

# %% [markdown]
# 6. Write a SQL query to see the ProductID and ProductName for those products where the ProductName includes the string "queso"

# %%
# %%sql
#     select product_id , product_name from products where product_name ilike '%queso%'
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 2 rows affected.
# [(11, 'Queso Cabrales'), (12, 'Queso Manchego La Pastora')]

# %% [markdown]
# 7. Write a query that shows the OrderID, CustomerID and ShipCountry for the orders where the ShipCountry is either France or Belgium.

# %%
# %%sql
#     select order_id , customer_id , ship_country from orders where ship_country = 'France' or ship_country = 'Belgium'
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 96 rows affected.
# [(10248, 'VINET', 'France'),
#  (10251, 'VICTE', 'France'),
#  (10252, 'SUPRD', 'Belgium'),
#  (10265, 'BLONP', 'France'),
#  (10274, 'VINET', 'France'),
#  (10295, 'VINET', 'France'),
#  (10297, 'BLONP', 'France'),
#  (10302, 'SUPRD', 'Belgium'),
#  (10311, 'DUMON', 'France'),
#  (10331, 'BONAP', 'France'),
#  (10334, 'VICTE', 'France'),
#  (10340, 'BONAP', 'France'),
#  (10350, 'LAMAI', 'France'),
#  (10358, 'LAMAI', 'France'),
#  (10360, 'BLONP', 'France'),
#  (10362, 'BONAP', 'France'),
#  (10371, 'LAMAI', 'France'),
#  (10408, 'FOLIG', 'France'),
#  (10413, 'LAMAI', 'France'),
#  (10425, 'LAMAI', 'France'),
#  (10436, 'BLONP', 'France'),
#  (10449, 'BLONP', 'France'),
#  (10450, 'VICTE', 'France'),
#  (10454, 'LAMAI', 'France'),
#  (10458, 'SUPRD', 'Belgium'),
#  (10459, 'VICTE', 'France'),
#  (10463, 'SUPRD', 'Belgium'),
#  (10470, 'BONAP', 'France'),
#  (10475, 'SUPRD', 'Belgium'),
#  (10478, 'VICTE', 'France'),
#  (10480, 'FOLIG', 'France'),
#  (10493, 'LAMAI', 'France'),
#  (10500, 'LAMAI', 'France'),
#  (10511, 'BONAP', 'France'),
#  (10525, 'BONAP', 'France'),
#  (10529, 'MAISD', 'Belgium'),
#  (10546, 'VICTE', 'France'),
#  (10559, 'BLONP', 'France'),
#  (10566, 'BLONP', 'France'),
#  (10584, 'BLONP', 'France'),
#  (10609, 'DUMON', 'France'),
#  (10610, 'LAMAI', 'France'),
#  (10628, 'BLONP', 'France'),
#  (10631, 'LAMAI', 'France'),
#  (10634, 'FOLIG', 'France'),
#  (10649, 'MAISD', 'Belgium'),
#  (10663, 'BONAP', 'France'),
#  (10671, 'FRANR', 'France'),
#  (10679, 'BLONP', 'France'),
#  (10683, 'DUMON', 'France'),
#  (10715, 'BONAP', 'France'),
#  (10730, 'BONAP', 'France'),
#  (10732, 'BONAP', 'France'),
#  (10737, 'VINET', 'France'),
#  (10738, 'SPECD', 'France'),
#  (10739, 'VINET', 'France'),
#  (10755, 'BONAP', 'France'),
#  (10760, 'MAISD', 'Belgium'),
#  (10763, 'FOLIG', 'France'),
#  (10767, 'SUPRD', 'Belgium'),
#  (10787, 'LAMAI', 'France'),
#  (10789, 'FOLIG', 'France'),
#  (10806, 'VICTE', 'France'),
#  (10814, 'VICTE', 'France'),
#  (10826, 'BLONP', 'France'),
#  (10827, 'BONAP', 'France'),
#  (10832, 'LAMAI', 'France'),
#  (10841, 'SUPRD', 'Belgium'),
#  (10843, 'VICTE', 'France'),
#  (10846, 'SUPRD', 'Belgium'),
#  (10850, 'VICTE', 'France'),
#  (10858, 'LACOR', 'France'),
#  (10860, 'FRANR', 'France'),
#  (10871, 'BONAP', 'France'),
#  (10876, 'BONAP', 'France'),
#  (10885, 'SUPRD', 'Belgium'),
#  (10890, 'DUMON', 'France'),
#  (10892, 'MAISD', 'Belgium'),
#  (10896, 'MAISD', 'Belgium'),
#  (10907, 'SPECD', 'France'),
#  (10923, 'LAMAI', 'France'),
#  (10927, 'LACOR', 'France'),
#  (10930, 'SUPRD', 'Belgium'),
#  (10932, 'BONAP', 'France'),
#  (10940, 'BONAP', 'France'),
#  (10964, 'SPECD', 'France'),
#  (10971, 'FRANR', 'France'),
#  (10972, 'LACOR', 'France'),
#  (10973, 'LACOR', 'France'),
#  (10978, 'MAISD', 'Belgium'),
#  (11004, 'MAISD', 'Belgium'),
#  (11035, 'SUPRD', 'Belgium'),
#  (11038, 'SUPRD', 'Belgium'),
#  (11043, 'SPECD', 'France'),
#  (11051, 'LAMAI', 'France'),
#  (11076, 'BONAP', 'France')]

# %% [markdown]
# 8. For all the employees table, show the FirstName, LastName, Title and BirthDate. Order the results by BirthDate, so we have the oldest employees first.

# %%
# %%sql
#     select first_name , last_name , title , birth_date from employees order by birth_date
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 9 rows affected.
# [('Margaret', 'Peacock', 'Sales Representative', datetime.date(1937, 9, 19)),
#  ('Nancy', 'Davolio', 'Sales Representative', datetime.date(1948, 12, 8)),
#  ('Andrew', 'Fuller', 'Vice President, Sales', datetime.date(1952, 2, 19)),
#  ('Steven', 'Buchanan', 'Sales Manager', datetime.date(1955, 3, 4)),
#  ('Laura', 'Callahan', 'Inside Sales Coordinator', datetime.date(1958, 1, 9)),
#  ('Robert', 'King', 'Sales Representative', datetime.date(1960, 5, 29)),
#  ('Michael', 'Suyama', 'Sales Representative', datetime.date(1963, 7, 2)),
#  ('Janet', 'Leverling', 'Sales Representative', datetime.date(1963, 8, 30)),
#  ('Anne', 'Dodsworth', 'Sales Representative', datetime.date(1966, 1, 27))]

# %% [markdown]
# 9. In the output of the query above, Show only the date portion of the BirthDate field.

# %%
# %%sql
#     select first_name , last_name , title , extract(day from birth_date)::integer as b_date from  employees order by birth_date
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 9 rows affected.
# [('Margaret', 'Peacock', 'Sales Representative', 19),
#  ('Nancy', 'Davolio', 'Sales Representative', 8),
#  ('Andrew', 'Fuller', 'Vice President, Sales', 19),
#  ('Steven', 'Buchanan', 'Sales Manager', 4),
#  ('Laura', 'Callahan', 'Inside Sales Coordinator', 9),
#  ('Robert', 'King', 'Sales Representative', 29),
#  ('Michael', 'Suyama', 'Sales Representative', 2),
#  ('Janet', 'Leverling', 'Sales Representative', 30),
#  ('Anne', 'Dodsworth', 'Sales Representative', 27)]

# %% [markdown]
# 10. Show the firstName and LastName columns from the Employees table, and then create a new column called FullName, showing FirstName and LastName joined together in one column, with a space in-between.

# %%
# %%sql
#     select first_name , last_name , first_name || ' ' || last_name as full_name from employees
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 9 rows affected.
# [('Nancy', 'Davolio', 'Nancy Davolio'),
#  ('Andrew', 'Fuller', 'Andrew Fuller'),
#  ('Janet', 'Leverling', 'Janet Leverling'),
#  ('Margaret', 'Peacock', 'Margaret Peacock'),
#  ('Steven', 'Buchanan', 'Steven Buchanan'),
#  ('Michael', 'Suyama', 'Michael Suyama'),
#  ('Robert', 'King', 'Robert King'),
#  ('Laura', 'Callahan', 'Laura Callahan'),
#  ('Anne', 'Dodsworth', 'Anne Dodsworth')]

# %% [markdown]
# 11. In the OrderDetails table, Create a new field, Total Price that multiplies UnitPrice and Quantity. In addition, show the OrderID, ProductID, UnitPrice and Quantity. Order by OrderID and ProductID.

# %%
# %%sql
#     SELECT unit_price*quantity total_price ,order_id, product_id, unit_price, quantity
#     FROM order_details
#     ORDER BY order_id, product_id;
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 2155 rows affected.
# [(168.0, 10248, 11, 14.0, 12),
#  (98.00000190734863, 10248, 42, 9.8, 10),
#  (173.99999618530273, 10248, 72, 34.8, 5),
#  (167.40000343322754, 10249, 14, 18.6, 9),
#  (1696.0000610351562, 10249, 51, 42.4, 40),
#  (76.99999809265137, 10250, 41, 7.7, 10),
#  (1484.0000534057617, 10250, 51, 42.4, 35),
#  (251.9999885559082, 10250, 65, 16.8, 15),
#  (100.79999542236328, 10251, 22, 16.8, 6),
#  (234.0000057220459, 10251, 57, 15.6, 15),
#  (335.99998474121094, 10251, 65, 16.8, 20),
#  (2592.0001220703125, 10252, 20, 64.8, 40),
#  (50.0, 10252, 33, 2.0, 25),
#  (1088.0000305175781, 10252, 60, 27.2, 40),
#  (200.0, 10253, 31, 10.0, 20),
#  (604.7999839782715, 10253, 39, 14.4, 42),
#  (640.0, 10253, 49, 16.0, 40),
#  (53.999998569488525, 10254, 24, 3.6, 15),
#  (403.2000160217285, 10254, 55, 19.2, 21),
#  (168.0, 10254, 74, 8.0, 21),
#  (303.99999618530273, 10255, 2, 15.2, 20),
#  (486.49998664855957, 10255, 16, 13.9, 35),
#  (379.9999952316284, 10255, 36, 15.2, 25),
#  (1320.0, 10255, 59, 44.0, 30),
#  (393.0000114440918, 10256, 53, 26.2, 15),
#  (124.79999542236328, 10256, 77, 10.4, 12),
#  (877.4999618530273, 10257, 27, 35.1, 25),
#  (86.39999771118164, 10257, 39, 14.4, 6),
#  (155.9999942779541, 10257, 77, 10.4, 15),
#  (759.9999904632568, 10258, 2, 15.2, 50),
#  (13.5, 10623, 24, 4.5, 3),
#  (540.0, 10623, 35, 18.0, 30),
#  (455.99998474121094, 10624, 28, 45.6, 10),
#  (742.7400054931641, 10624, 29, 123.79, 6),
#  (194.50000762939453, 10624, 44, 19.45, 10),
#  (69.75, 10625, 14, 23.25, 3),
#  (70.0, 10625, 42, 14.0, 5),
#  (340.0, 10625, 60, 34.0, 10),
#  ...]

# %% [markdown]
# 12. How many customers do we have in the Customers table? Show one value only.

# %%
# %%sql
#     select count(DISTINCT customer_id) from customers;
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 1 rows affected.
# [(91,)]

# %% [markdown]
# 13. Show the date of the first order ever made in the Orders table.

# %%
# %%sql
#     SELECT MIN(order_date)
#     FROM orders
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 1 rows affected.
# [(datetime.date(1996, 7, 4),)]

# %% [markdown]
# 14. Show a list of countries where the Northwind company has customers.

# %%
# %%sql
#     select DISTINCT(country) from customers
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 21 rows affected.
# [('Argentina',),
#  ('Spain',),
#  ('Switzerland',),
#  ('Italy',),
#  ('Venezuela',),
#  ('Belgium',),
#  ('Norway',),
#  ('Sweden',),
#  ('USA',),
#  ('France',),
#  ('Mexico',),
#  ('Brazil',),
#  ('Austria',),
#  ('Poland',),
#  ('UK',),
#  ('Ireland',),
#  ('Germany',),
#  ('Denmark',),
#  ('Canada',),
#  ('Finland',),
#  ('Portugal',)]

# %% [markdown]
# 15. Show a list of all the diffrent values in the Customers table for ContactTitles. Also, include count for each ContactTitle

# %%
# %%sql
#     select contact_title , count(contact_title) from customers group by contact_title
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 12 rows affected.
# [('Sales Manager', 11),
#  ('Owner', 17),
#  ('Owner/Marketing Assistant', 1),
#  ('Accounting Manager', 10),
#  ('Sales Associate', 7),
#  ('Sales Agent', 5),
#  ('Assistant Sales Agent', 2),
#  ('Assistant Sales Representative', 1),
#  ('Order Administrator', 2),
#  ('Marketing Manager', 12),
#  ('Sales Representative', 17),
#  ('Marketing Assistant', 6)]

# %% [markdown]
# 16. Show the ProductID, ProductName, and the CompanyName of the Supplier. Sort by ProductID. (Hint: use Products and Suppliers Table)

# %%
# %%sql
#     select product_id , product_name , company_name
#     from products , suppliers
#     where products.product_id = suppliers.supplier_id
#     order by product_id
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 29 rows affected.
# [(1, 'Chai', 'Exotic Liquids'),
#  (2, 'Chang', 'New Orleans Cajun Delights'),
#  (3, 'Aniseed Syrup', "Grandma Kelly's Homestead"),
#  (4, "Chef Anton's Cajun Seasoning", 'Tokyo Traders'),
#  (5, "Chef Anton's Gumbo Mix", "Cooperativa de Quesos 'Las Cabras'"),
#  (6, "Grandma's Boysenberry Spread", "Mayumi's"),
#  (7, "Uncle Bob's Organic Dried Pears", 'Pavlova, Ltd.'),
#  (8, 'Northwoods Cranberry Sauce', 'Specialty Biscuits, Ltd.'),
#  (9, 'Mishi Kobe Niku', 'PB Knäckebröd AB'),
#  (10, 'Ikura', 'Refrescos Americanas LTDA'),
#  (11, 'Queso Cabrales', 'Heli Süßwaren GmbH & Co. KG'),
#  (12, 'Queso Manchego La Pastora', 'Plutzer Lebensmittelgroßmärkte AG'),
#  (13, 'Konbu', 'Nord-Ost-Fisch Handelsgesellschaft mbH'),
#  (14, 'Tofu', 'Formaggi Fortini s.r.l.'),
#  (15, 'Genen Shouyu', 'Norske Meierier'),
#  (16, 'Pavlova', 'Bigfoot Breweries'),
#  (17, 'Alice Mutton', 'Svensk Sjöföda AB'),
#  (18, 'Carnarvon Tigers', 'Aux joyeux ecclésiastiques'),
#  (19, 'Teatime Chocolate Biscuits', 'New England Seafood Cannery'),
#  (20, "Sir Rodney's Marmalade", 'Leka Trading'),
#  (21, "Sir Rodney's Scones", 'Lyngbysild'),
#  (22, "Gustaf's Knäckebröd", 'Zaanse Snoepfabriek'),
#  (23, 'Tunnbröd', 'Karkki Oy'),
#  (24, 'Guaraná Fantástica', "G'day, Mate"),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 'Ma Maison'),
#  (26, 'Gumbär Gummibärchen', 'Pasta Buttini s.r.l.'),
#  (27, 'Schoggi Schokolade', 'Escargots Nouveaux'),
#  (28, 'Rössle Sauerkraut', 'Gai pâturage'),
#  (29, 'Thüringer Rostbratwurst', "Forêts d'érables")]

# %% [markdown]
# 17. Show the OrderID, OrderDate(date only) and CompanyName of the Shipper, and sort by OrderID. ALso, Show only those rows with an OrderID of less than 10300.

# %%
# %%sql
#     select order_id , order_date , company_name from orders , shippers
#     where orders.ship_via = shippers.shipper_id and order_id < 10300
#     order by order_id
# Out:
#    postgresql://postgres:***@localhost/DVDRental
#  * postgresql://postgres:***@localhost/NorthWind
# 52 rows affected.
# [(10248, datetime.date(1996, 7, 4), 'Federal Shipping'),
#  (10249, datetime.date(1996, 7, 5), 'Speedy Express'),
#  (10250, datetime.date(1996, 7, 8), 'United Package'),
#  (10251, datetime.date(1996, 7, 8), 'Speedy Express'),
#  (10252, datetime.date(1996, 7, 9), 'United Package'),
#  (10253, datetime.date(1996, 7, 10), 'United Package'),
#  (10254, datetime.date(1996, 7, 11), 'United Package'),
#  (10255, datetime.date(1996, 7, 12), 'Federal Shipping'),
#  (10256, datetime.date(1996, 7, 15), 'United Package'),
#  (10257, datetime.date(1996, 7, 16), 'Federal Shipping'),
#  (10258, datetime.date(1996, 7, 17), 'Speedy Express'),
#  (10259, datetime.date(1996, 7, 18), 'Federal Shipping'),
#  (10260, datetime.date(1996, 7, 19), 'Speedy Express'),
#  (10261, datetime.date(1996, 7, 19), 'United Package'),
#  (10262, datetime.date(1996, 7, 22), 'Federal Shipping'),
#  (10263, datetime.date(1996, 7, 23), 'Federal Shipping'),
#  (10264, datetime.date(1996, 7, 24), 'Federal Shipping'),
#  (10265, datetime.date(1996, 7, 25), 'Speedy Express'),
#  (10266, datetime.date(1996, 7, 26), 'Federal Shipping'),
#  (10267, datetime.date(1996, 7, 29), 'Speedy Express'),
#  (10268, datetime.date(1996, 7, 30), 'Federal Shipping'),
#  (10269, datetime.date(1996, 7, 31), 'Speedy Express'),
#  (10270, datetime.date(1996, 8, 1), 'Speedy Express'),
#  (10271, datetime.date(1996, 8, 1), 'United Package'),
#  (10272, datetime.date(1996, 8, 2), 'United Package'),
#  (10273, datetime.date(1996, 8, 5), 'Federal Shipping'),
#  (10274, datetime.date(1996, 8, 6), 'Speedy Express'),
#  (10275, datetime.date(1996, 8, 7), 'Speedy Express'),
#  (10276, datetime.date(1996, 8, 8), 'Federal Shipping'),
#  (10277, datetime.date(1996, 8, 9), 'Federal Shipping'),
#  (10278, datetime.date(1996, 8, 12), 'United Package'),
#  (10279, datetime.date(1996, 8, 13), 'United Package'),
#  (10280, datetime.date(1996, 8, 14), 'Speedy Express'),
#  (10281, datetime.date(1996, 8, 14), 'Speedy Express'),
#  (10282, datetime.date(1996, 8, 15), 'Speedy Express'),
#  (10283, datetime.date(1996, 8, 16), 'Federal Shipping'),
#  (10284, datetime.date(1996, 8, 19), 'Speedy Express'),
#  (10285, datetime.date(1996, 8, 20), 'United Package'),
#  (10286, datetime.date(1996, 8, 21), 'Federal Shipping'),
#  (10287, datetime.date(1996, 8, 22), 'Federal Shipping'),
#  (10288, datetime.date(1996, 8, 23), 'Speedy Express'),
#  (10289, datetime.date(1996, 8, 26), 'Federal Shipping'),
#  (10290, datetime.date(1996, 8, 27), 'Speedy Express'),
#  (10291, datetime.date(1996, 8, 27), 'United Package'),
#  (10292, datetime.date(1996, 8, 28), 'United Package'),
#  (10293, datetime.date(1996, 8, 29), 'Federal Shipping'),
#  (10294, datetime.date(1996, 8, 30), 'United Package'),
#  (10295, datetime.date(1996, 9, 2), 'United Package'),
#  (10296, datetime.date(1996, 9, 3), 'Speedy Express'),
#  (10297, datetime.date(1996, 9, 4), 'United Package'),
#  (10298, datetime.date(1996, 9, 5), 'United Package'),
#  (10299, datetime.date(1996, 9, 6), 'United Package')]

# %% [markdown]
# ## Use DVD Rental Database
# #Connect with database

# %%
# %sql postgresql://postgres:himanshu@localhost/DVDRental
engine = create_engine('postgresql://postgres:himanshu@localhost/DVDRental')

# %% [markdown]
# 18. Find the difference between the total number of CITY entries in the table and the number of distinct CITY entries in the table.

# %%
# %%sql
#     select count(city) - count(distinct city) as difference from city
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 1 rows affected.
# [(1,)]

# %% [markdown]
# 19. Find the duplicate city enteries in the city table

# %%
# %%sql
#     select city from city
#     group by city
#     having count(*) > 1
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 1 rows affected.
# [('London',)]

# %% [markdown]
# 20. Find all the cities with even city_id.

# %%
# %%sql
#     select city_id , city from city
#     where city_id % 2 = 0
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 300 rows affected.
# [(2, 'Abha'),
#  (4, 'Acua'),
#  (6, 'Addis Abeba'),
#  (8, 'Adoni'),
#  (10, 'Akishima'),
#  (12, 'al-Ayn'),
#  (14, 'al-Manama'),
#  (16, 'al-Qatif'),
#  (18, 'Allappuzha (Alleppey)'),
#  (20, 'Almirante Brown'),
#  (22, 'Ambattur'),
#  (24, 'Amroha'),
#  (26, 'Anpolis'),
#  (28, 'Aparecida de Goinia'),
#  (30, 'Araatuba'),
#  (32, 'Arecibo'),
#  (34, 'Ashdod'),
#  (36, 'Ashqelon'),
#  (38, 'Athenai'),
#  (40, 'Atlixco'),
#  (42, 'Aurora'),
#  (44, 'Bag'),
#  (46, 'Baicheng'),
#  (48, 'Baku'),
#  (50, 'Balikesir'),
#  (52, 'Bamenda'),
#  (54, 'Banjul'),
#  (56, 'Basel'),
#  (58, 'Batman'),
#  (60, 'Battambang'),
#  (62, 'Bayugan'),
#  (64, 'Beira'),
#  (66, 'Belm'),
#  (68, 'Beni-Mellal'),
#  (70, 'Bergamo'),
#  (72, 'Bern'),
#  (74, 'Bhilwara'),
#  (76, 'Bhopal'),
#  (78, 'Bijapur'),
#  (80, 'Binzhou'),
#  (82, 'Bislig'),
#  (84, 'Boa Vista'),
#  (86, 'Botosani'),
#  (88, 'Bradford'),
#  (90, 'Bratislava'),
#  (92, 'Brest'),
#  (94, 'Brockton'),
#  (96, 'Buenaventura'),
#  (98, 'Cabuyao'),
#  (100, 'Cam Ranh'),
#  (102, 'Caracas'),
#  (104, 'Cavite'),
#  (106, 'Celaya'),
#  (108, 'Changhwa'),
#  (110, 'Chapra'),
#  (112, 'Chatsworth'),
#  (114, 'Chiayi'),
#  (116, 'Chungho'),
#  (118, 'Ciomas'),
#  (120, 'Citrus Heights'),
#  (122, 'Ciudad del Este'),
#  (124, 'Coacalco de Berriozbal'),
#  (126, 'Compton'),
#  (128, 'Crdoba'),
#  (130, 'Cuautla'),
#  (132, 'Cuman'),
#  (134, 'Dadu'),
#  (136, 'Datong'),
#  (138, 'Davao'),
#  (140, 'Dayton'),
#  (142, 'Denizli'),
#  (144, 'Dhule (Dhulia)'),
#  (146, 'Donostia-San Sebastin'),
#  (148, 'Duisburg'),
#  (150, 'Dzerzinsk'),
#  (152, 'Effon-Alaiye'),
#  (154, 'El Fuerte'),
#  (156, 'Elista'),
#  (158, 'Emmen'),
#  (160, 'Erlangen'),
#  (162, 'Esfahan'),
#  (164, 'Etawah'),
#  (166, 'Ezhou'),
#  (168, 'Fengshan'),
#  (170, 'Florencia'),
#  (172, 'Fukuyama'),
#  (174, 'Fuyu'),
#  (176, 'Gandhinagar'),
#  (178, 'Garland'),
#  (180, 'Gaziantep'),
#  (182, 'Gingoog'),
#  (184, 'Gorontalo'),
#  (186, 'Graz'),
#  (188, 'Guadalajara'),
#  (190, 'guas Lindas de Gois'),
#  (192, 'Hagonoy'),
#  (194, 'Haiphong'),
#  (196, 'Halifax'),
#  (198, 'Halle/Saale'),
#  (200, 'Hamilton'),
#  (202, 'Hidalgo'),
#  (204, 'Hino'),
#  (206, 'Hodeida'),
#  (208, 'Hoshiarpur'),
#  (210, 'Huaian'),
#  (212, 'Huejutla de Reyes'),
#  (214, 'Hunuco'),
#  (216, 'Idfu'),
#  (218, 'Ikerre'),
#  (220, 'Ilorin'),
#  (222, 'Inegl'),
#  (224, 'Isesaki'),
#  (226, 'Iwaki'),
#  (228, 'Iwatsuki'),
#  (230, 'Jaffna'),
#  (232, 'Jakarta'),
#  (234, 'Jamalpur'),
#  (236, 'Jastrzebie-Zdrj'),
#  (238, 'Jelets'),
#  (240, 'Jinchang'),
#  (242, 'Jinzhou'),
#  (244, 'Johannesburg'),
#  (246, 'Jos Azueta'),
#  (248, 'Juiz de Fora'),
#  (250, 'Jurez'),
#  (252, 'Kaduna'),
#  (254, 'Kaliningrad'),
#  (256, 'Kamakura'),
#  (258, 'Kamjanets-Podilskyi'),
#  (260, 'Kanazawa'),
#  (262, 'Kansas City'),
#  (264, 'Katihar'),
#  (266, 'Kilis'),
#  (268, 'Kimchon'),
#  (270, 'Kirovo-Tepetsk'),
#  (272, 'Kitwe'),
#  (274, 'Kolpino'),
#  (276, 'Koriyama'),
#  (278, 'Korolev'),
#  (280, 'Kragujevac'),
#  (282, 'Kuching'),
#  (284, 'Kurashiki'),
#  (286, 'Kursk'),
#  (288, 'La Paz'),
#  (290, 'La Romana'),
#  (292, 'Lancaster'),
#  (294, 'Lapu-Lapu'),
#  (296, 'Lausanne'),
#  (298, 'Lengshuijiang'),
#  (300, 'Lethbridge'),
#  (302, 'Liaocheng'),
#  (304, 'Lilongwe'),
#  (306, 'Lincoln'),
#  (308, 'Lipetsk'),
#  (310, 'Ljubertsy'),
#  (312, 'London'),
#  (314, 'Lublin'),
#  (316, 'Lungtan'),
#  (318, 'Madiun'),
#  (320, 'Maikop'),
#  (322, 'Manchester'),
#  (324, 'Mandi Bahauddin'),
#  (326, 'Maracabo'),
#  (328, 'Maring'),
#  (330, 'Matamoros'),
#  (332, 'Meixian'),
#  (334, 'Merlo'),
#  (336, 'Miraj'),
#  (338, 'Miyakonojo'),
#  (340, 'Molodetno'),
#  (342, 'Monywa'),
#  (344, 'Mosul'),
#  (346, 'Munger (Monghyr)'),
#  (348, 'Mwene-Ditu'),
#  (350, 'Mysore'),
#  (352, 'Nabereznyje Telny'),
#  (354, 'Nagaon'),
#  (356, 'Najafabad'),
#  (358, 'Nakhon Sawan'),
#  (360, 'Namibe'),
#  (362, 'Nanyang'),
#  (364, 'Newcastle'),
#  (366, 'Nha Trang'),
#  (368, 'Novi Sad'),
#  (370, 'Nukualofa'),
#  (372, 'Nyeri'),
#  (374, 'Ogbomosho'),
#  (376, 'Okayama'),
#  (378, 'Olomouc'),
#  (380, 'Omiya'),
#  (382, 'Onomichi'),
#  (384, 'Osmaniye'),
#  (386, 'Otsu'),
#  (388, 'Ourense (Orense)'),
#  (390, 'Oyo'),
#  (392, 'Paarl'),
#  (394, 'Pak Kret'),
#  (396, 'Pangkal Pinang'),
#  (398, 'Parbhani'),
#  (400, 'Patiala'),
#  (402, 'Pavlodar'),
#  (404, 'Peoria'),
#  (406, 'Phnom Penh'),
#  (408, 'Pjatigorsk'),
#  (410, 'Po'),
#  (412, 'Pontianak'),
#  (414, 'Portoviejo'),
#  (416, 'Pudukkottai'),
#  (418, 'Purnea (Purnia)'),
#  (420, 'Pyongyang'),
#  (422, 'Qinhuangdao'),
#  (424, 'Quilmes'),
#  (426, 'Rajkot'),
#  (428, 'Rancagua'),
#  (430, 'Richmond Hill'),
#  (432, 'Rizhao'),
#  (434, 'Robamba'),
#  (436, 'Ruse'),
#  (438, 's-Hertogenbosch'),
#  (440, 'Sagamihara'),
#  (442, 'Saint-Denis'),
#  (444, 'Salala'),
#  (446, 'Salinas'),
#  (448, 'Sambhal'),
#  (450, 'San Felipe de Puerto Plata'),
#  (452, 'San Juan Bautista Tuxtepec'),
#  (454, 'San Miguel de Tucumn'),
#  (456, 'Santa Brbara dOeste'),
#  (458, 'Santa Rosa'),
#  (460, 'Santiago de los Caballeros'),
#  (462, 'Sanya'),
#  (464, 'Satna'),
#  (466, 'Serpuhov'),
#  (468, 'Shanwei'),
#  (470, 'Sharja'),
#  (472, 'Shikarpur'),
#  (474, 'Shimonoseki'),
#  (476, 'Shubra al-Khayma'),
#  (478, 'Siliguri (Shiliguri)'),
#  (480, 'Sincelejo'),
#  (482, 'Sivas'),
#  (484, 'Smolensk'),
#  (486, 'So Leopoldo'),
#  (488, 'Sokoto'),
#  (490, 'Sorocaba'),
#  (492, 'Sousse'),
#  (494, 'Southampton'),
#  (496, 'Southport'),
#  (498, 'Stara Zagora'),
#  (500, 'Stockport'),
#  (502, 'Suihua'),
#  (504, 'Sultanbeyli'),
#  (506, 'Sumy'),
#  (508, 'Sunnyvale'),
#  (510, 'Syktyvkar'),
#  (512, 'Szkesfehrvr'),
#  (514, 'Tabriz'),
#  (516, 'Tafuna'),
#  (518, 'Taizz'),
#  (520, 'Tallahassee'),
#  (522, 'Tambaram'),
#  (524, 'Tandil'),
#  (526, 'Tanshui'),
#  (528, 'Tarlac'),
#  (530, 'Tartu'),
#  (532, 'Tegal'),
#  (534, 'Tete'),
#  (536, 'Tiefa'),
#  (538, 'Tokat'),
#  (540, 'Tongliao'),
#  (542, 'Touliu'),
#  (544, 'Toulouse'),
#  (546, 'Tsaotun'),
#  (548, 'Tuguegarao'),
#  (550, 'Udaipur'),
#  (552, 'Ueda'),
#  (554, 'Uluberia'),
#  (556, 'Uruapan'),
#  (558, 'Usolje-Sibirskoje'),
#  (560, 'Vaduz'),
#  (562, 'Valle de la Pascua'),
#  (564, 'Valparai'),
#  (566, 'Varanasi (Benares)'),
#  (568, 'Vijayawada'),
#  (570, 'Vilnius'),
#  (572, 'Vitria de Santo Anto'),
#  (574, 'Weifang'),
#  (576, 'Woodridge'),
#  (578, 'Xiangfan'),
#  (580, 'Xintai'),
#  (582, 'Yamuna Nagar'),
#  (584, 'Yantai'),
#  (586, 'Yerevan'),
#  (588, 'Yingkou'),
#  (590, 'Yuncheng'),
#  (592, 'Zalantun'),
#  (594, 'Zaoyang'),
#  (596, 'Zaria'),
#  (598, 'Zhezqazghan'),
#  (600, 'Ziguinchor')]

# %% [markdown]
# 21. Find all the cities with odd city_id.

# %%
# %%sql
#     select city_id , city from city
#     where city_id % 2 = 1
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 300 rows affected.
# [(1, 'A Corua (La Corua)'),
#  (3, 'Abu Dhabi'),
#  (5, 'Adana'),
#  (7, 'Aden'),
#  (9, 'Ahmadnagar'),
#  (11, 'Akron'),
#  (13, 'al-Hawiya'),
#  (15, 'al-Qadarif'),
#  (17, 'Alessandria'),
#  (19, 'Allende'),
#  (21, 'Alvorada'),
#  (23, 'Amersfoort'),
#  (25, 'Angra dos Reis'),
#  (27, 'Antofagasta'),
#  (29, 'Apeldoorn'),
#  (31, 'Arak'),
#  (33, 'Arlington'),
#  (35, 'Ashgabat'),
#  (37, 'Asuncin'),
#  (39, 'Atinsk'),
#  (41, 'Augusta-Richmond County'),
#  (43, 'Avellaneda'),
#  (45, 'Baha Blanca'),
#  (47, 'Baiyin'),
#  (49, 'Balaiha'),
#  (51, 'Balurghat'),
#  (53, 'Bandar Seri Begawan'),
#  (55, 'Barcelona'),
#  (57, 'Bat Yam'),
#  (59, 'Batna'),
#  (61, 'Baybay'),
#  (63, 'Bchar'),
#  (65, 'Bellevue'),
#  (67, 'Benguela'),
#  (69, 'Benin City'),
#  (71, 'Berhampore (Baharampur)'),
#  (73, 'Bhavnagar'),
#  (75, 'Bhimavaram'),
#  (77, 'Bhusawal'),
#  (79, 'Bilbays'),
#  (81, 'Birgunj'),
#  (83, 'Blumenau'),
#  (85, 'Boksburg'),
#  (87, 'Botshabelo'),
#  (89, 'Braslia'),
#  (91, 'Brescia'),
#  (93, 'Brindisi'),
#  (95, 'Bucuresti'),
#  (97, 'Bydgoszcz'),
#  (99, 'Callao'),
#  (101, 'Cape Coral'),
#  (103, 'Carmen'),
#  (105, 'Cayenne'),
#  (107, 'Chandrapur'),
#  (109, 'Changzhou'),
#  (111, 'Charlotte Amalie'),
#  (113, 'Cheju'),
#  (115, 'Chisinau'),
#  (117, 'Cianjur'),
#  (119, 'Ciparay'),
#  (121, 'Citt del Vaticano'),
#  (123, 'Clarksville'),
#  (125, 'Coatzacoalcos'),
#  (127, 'Coquimbo'),
#  (129, 'Cuauhtmoc'),
#  (131, 'Cuernavaca'),
#  (133, 'Czestochowa'),
#  (135, 'Dallas'),
#  (137, 'Daugavpils'),
#  (139, 'Daxian'),
#  (141, 'Deba Habe'),
#  (143, 'Dhaka'),
#  (145, 'Dongying'),
#  (147, 'Dos Quebradas'),
#  (149, 'Dundee'),
#  (151, 'Ede'),
#  (153, 'El Alto'),
#  (155, 'El Monte'),
#  (157, 'Emeishan'),
#  (159, 'Enshi'),
#  (161, 'Escobar'),
#  (163, 'Eskisehir'),
#  (165, 'Ezeiza'),
#  (167, 'Faaa'),
#  (169, 'Firozabad'),
#  (171, 'Fontana'),
#  (173, 'Funafuti'),
#  (175, 'Fuzhou'),
#  (177, 'Garden Grove'),
#  (179, 'Gatineau'),
#  (181, 'Gijn'),
#  (183, 'Goinia'),
#  (185, 'Grand Prairie'),
#  (187, 'Greensboro'),
#  (189, 'Guaruj'),
#  (191, 'Gulbarga'),
#  (193, 'Haining'),
#  (195, 'Haldia'),
#  (197, 'Halisahar'),
#  (199, 'Hami'),
#  (201, 'Hanoi'),
#  (203, 'Higashiosaka'),
#  (205, 'Hiroshima'),
#  (207, 'Hohhot'),
#  (209, 'Hsichuh'),
#  (211, 'Hubli-Dharwad'),
#  (213, 'Huixquilucan'),
#  (215, 'Ibirit'),
#  (217, 'Ife'),
#  (219, 'Iligan'),
#  (221, 'Imus'),
#  (223, 'Ipoh'),
#  (225, 'Ivanovo'),
#  (227, 'Iwakuni'),
#  (229, 'Izumisano'),
#  (231, 'Jaipur'),
#  (233, 'Jalib al-Shuyukh'),
#  (235, 'Jaroslavl'),
#  (237, 'Jedda'),
#  (239, 'Jhansi'),
#  (241, 'Jining'),
#  (243, 'Jodhpur'),
#  (245, 'Joliet'),
#  (247, 'Juazeiro do Norte'),
#  (249, 'Junan'),
#  (251, 'Kabul'),
#  (253, 'Kakamigahara'),
#  (255, 'Kalisz'),
#  (257, 'Kamarhati'),
#  (259, 'Kamyin'),
#  (261, 'Kanchrapara'),
#  (263, 'Karnal'),
#  (265, 'Kermanshah'),
#  (267, 'Kimberley'),
#  (269, 'Kingstown'),
#  (271, 'Kisumu'),
#  (273, 'Klerksdorp'),
#  (275, 'Konotop'),
#  (277, 'Korla'),
#  (279, 'Kowloon and New Kowloon'),
#  (281, 'Ktahya'),
#  (283, 'Kumbakonam'),
#  (285, 'Kurgan'),
#  (287, 'Kuwana'),
#  (289, 'La Plata'),
#  (291, 'Laiwu'),
#  (293, 'Laohekou'),
#  (295, 'Laredo'),
#  (297, 'Le Mans'),
#  (299, 'Leshan'),
#  (301, 'Lhokseumawe'),
#  (303, 'Liepaja'),
#  (305, 'Lima'),
#  (307, 'Linz'),
#  (309, 'Livorno'),
#  (311, 'Loja'),
#  (313, 'London'),
#  (315, 'Lubumbashi'),
#  (317, 'Luzinia'),
#  (319, 'Mahajanga'),
#  (321, 'Malm'),
#  (323, 'Mandaluyong'),
#  (325, 'Mannheim'),
#  (327, 'Mardan'),
#  (329, 'Masqat'),
#  (331, 'Matsue'),
#  (333, 'Memphis'),
#  (335, 'Mexicali'),
#  (337, 'Mit Ghamr'),
#  (339, 'Mogiljov'),
#  (341, 'Monclova'),
#  (343, 'Moscow'),
#  (345, 'Mukateve'),
#  (347, 'Mwanza'),
#  (349, 'Myingyan'),
#  (351, 'Naala-Porto'),
#  (353, 'Nador'),
#  (355, 'Nagareyama'),
#  (357, 'Naju'),
#  (359, 'Nam Dinh'),
#  (361, 'Nantou'),
#  (363, 'NDjamna'),
#  (365, 'Nezahualcyotl'),
#  (367, 'Niznekamsk'),
#  (369, 'Novoterkassk'),
#  (371, 'Nuuk'),
#  (373, 'Ocumare del Tuy'),
#  (375, 'Okara'),
#  (377, 'Okinawa'),
#  (379, 'Omdurman'),
#  (381, 'Ondo'),
#  (383, 'Oshawa'),
#  (385, 'ostka'),
#  (387, 'Oulu'),
#  (389, 'Owo'),
#  (391, 'Ozamis'),
#  (393, 'Pachuca de Soto'),
#  (395, 'Palghat (Palakkad)'),
#  (397, 'Papeete'),
#  (399, 'Pathankot'),
#  (401, 'Patras'),
#  (403, 'Pemalang'),
#  (405, 'Pereira'),
#  (407, 'Pingxiang'),
#  (409, 'Plock'),
#  (411, 'Ponce'),
#  (413, 'Poos de Caldas'),
#  (415, 'Probolinggo'),
#  (417, 'Pune'),
#  (419, 'Purwakarta'),
#  (421, 'Qalyub'),
#  (423, 'Qomsheh'),
#  (425, 'Rae Bareli'),
#  (427, 'Rampur'),
#  (429, 'Ranchi'),
#  (431, 'Rio Claro'),
#  (433, 'Roanoke'),
#  (435, 'Rockford'),
#  (437, 'Rustenburg'),
#  (439, 'Saarbrcken'),
#  (441, 'Saint Louis'),
#  (443, 'Sal'),
#  (445, 'Salamanca'),
#  (447, 'Salzburg'),
#  (449, 'San Bernardino'),
#  (451, 'San Felipe del Progreso'),
#  (453, 'San Lorenzo'),
#  (455, 'Sanaa'),
#  (457, 'Santa F'),
#  (459, 'Santiago de Compostela'),
#  (461, 'Santo Andr'),
#  (463, 'Sasebo'),
#  (465, 'Sawhaj'),
#  (467, 'Shahr-e Kord'),
#  (469, 'Shaoguan'),
#  (471, 'Shenzhen'),
#  (473, 'Shimoga'),
#  (475, 'Shivapuri'),
#  (477, 'Siegen'),
#  (479, 'Simferopol'),
#  (481, 'Sirjan'),
#  (483, 'Skikda'),
#  (485, 'So Bernardo do Campo'),
#  (487, 'Sogamoso'),
#  (489, 'Songkhla'),
#  (491, 'Soshanguve'),
#  (493, 'South Hill'),
#  (495, 'Southend-on-Sea'),
#  (497, 'Springs'),
#  (499, 'Sterling Heights'),
#  (501, 'Sucre'),
#  (503, 'Sullana'),
#  (505, 'Sumqayit'),
#  (507, 'Sungai Petani'),
#  (509, 'Surakarta'),
#  (511, 'Syrakusa'),
#  (513, 'Tabora'),
#  (515, 'Tabuk'),
#  (517, 'Taguig'),
#  (519, 'Talavera'),
#  (521, 'Tama'),
#  (523, 'Tanauan'),
#  (525, 'Tangail'),
#  (527, 'Tanza'),
#  (529, 'Tarsus'),
#  (531, 'Teboksary'),
#  (533, 'Tel Aviv-Jaffa'),
#  (535, 'Tianjin'),
#  (537, 'Tieli'),
#  (539, 'Tonghae'),
#  (541, 'Torren'),
#  (543, 'Toulon'),
#  (545, 'Trshavn'),
#  (547, 'Tsuyama'),
#  (549, 'Tychy'),
#  (551, 'Udine'),
#  (553, 'Uijongbu'),
#  (555, 'Urawa'),
#  (557, 'Usak'),
#  (559, 'Uttarpara-Kotrung'),
#  (561, 'Valencia'),
#  (563, 'Valle de Santiago'),
#  (565, 'Vancouver'),
#  (567, 'Vicente Lpez'),
#  (569, 'Vila Velha'),
#  (571, 'Vinh'),
#  (573, 'Warren'),
#  (575, 'Witten'),
#  (577, 'Wroclaw'),
#  (579, 'Xiangtan'),
#  (581, 'Xinxiang'),
#  (583, 'Yangor'),
#  (585, 'Yaound'),
#  (587, 'Yinchuan'),
#  (589, 'York'),
#  (591, 'Yuzhou'),
#  (593, 'Zanzibar'),
#  (595, 'Zapopan'),
#  (597, 'Zeleznogorsk'),
#  (599, 'Zhoushan')]

# %% [markdown]
# 22. Query the two cities in city table with the shortest and longest CITY names, as well as their respective lengths (i.e.: number of characters in the name). If there is more than one smallest or largest city, choose the one that comes first when ordered alphabetically.

# %%
# %%sql
#     (select city, length(city) from city order by length(city) asc, city asc limit 1)
#     union
#     (select city, length(city) from city order by length(city) desc, city desc limit 1)
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 2 rows affected.
# [('Po', 2), ('Santiago de los Caballeros', 26)]

# %% [markdown]
# 23. Query the list of country names starting with vowels (i.e., a, e, i, o, or u) from country table. Your result cannot contain duplicates.

# %%
# %%sql
#     SELECT DISTINCT
#     COUNTRY
#     FROM COUNTRY
#     WHERE lower(substr(COUNTRY,1,1)) in ('a','e','i','o','u')
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 25 rows affected.
# [('Iraq',),
#  ('Ukraine',),
#  ('Argentina',),
#  ('Indonesia',),
#  ('Italy',),
#  ('Ecuador',),
#  ('United Arab Emirates',),
#  ('Azerbaijan',),
#  ('Oman',),
#  ('Egypt',),
#  ('Afghanistan',),
#  ('India',),
#  ('Iran',),
#  ('Algeria',),
#  ('Armenia',),
#  ('Estonia',),
#  ('United Kingdom',),
#  ('Israel',),
#  ('Austria',),
#  ('Australia',),
#  ('Ethiopia',),
#  ('American Samoa',),
#  ('Angola',),
#  ('Anguilla',),
#  ('United States',)]

# %% [markdown]
# 24. Query the list of country names ending with vowels (a, e, i, o, u) from country table. Your result cannot contain duplicates.

# %%
# %%sql
#     SELECT DISTINCT
#     COUNTRY
#     FROM COUNTRY
#     WHERE lower(substr(COUNTRY,length(country),1)) in ('a','e','i','o','u')
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 54 rows affected.
# [('Nigeria',),
#  ('Mozambique',),
#  ('Indonesia',),
#  ('Venezuela',),
#  ('China',),
#  ('Congo, The Democratic Republic of the',),
#  ('Armenia',),
#  ('Romania',),
#  ('Austria',),
#  ('Australia',),
#  ('Cambodia',),
#  ('Bolivia',),
#  ('Sri Lanka',),
#  ('Ethiopia',),
#  ('Canada',),
#  ('American Samoa',),
#  ('Brunei',),
#  ('Angola',),
#  ('South Korea',),
#  ('Anguilla',),
#  ('Colombia',),
#  ('Ukraine',),
#  ('Saudi Arabia',),
#  ('Lithuania',),
#  ('Bulgaria',),
#  ('Argentina',),
#  ('Tunisia',),
#  ('Latvia',),
#  ('North Korea',),
#  ('Greece',),
#  ('Puerto Rico',),
#  ('India',),
#  ('Morocco',),
#  ('Malawi',),
#  ('Moldova',),
#  ('French Polynesia',),
#  ('Chile',),
#  ('Algeria',),
#  ('Gambia',),
#  ('France',),
#  ('Estonia',),
#  ('Slovakia',),
#  ('South Africa',),
#  ('Mexico',),
#  ('Peru',),
#  ('Nauru',),
#  ('Tonga',),
#  ('Tanzania',),
#  ('Malaysia',),
#  ('Kenya',),
#  ('Zambia',),
#  ('Yugoslavia',),
#  ('French Guiana',),
#  ('Tuvalu',)]

# %% [markdown]
# 25. Query the list of country names from country which have vowels (i.e., a, e, i, o, and u) as both their first and last characters. Your result cannot contain duplicates.

# %%
# %%sql
#     SELECT DISTINCT city
#     FROM city
#     WHERE city SIMILAR TO '(a|e|i|o|u|A|E|I|O|U)%(a|e|i|o|u|A|E|I|O|U)';
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 59 rows affected.
# [('Elista',),
#  ('al-Hawiya',),
#  ('Araatuba',),
#  ('Atlixco',),
#  ('Okara',),
#  ('Aparecida de Goinia',),
#  ('Effon-Alaiye',),
#  ('Uluberia',),
#  ('Okinawa',),
#  ('Osmaniye',),
#  ('Iwakuni',),
#  ('Alessandria',),
#  ('Ondo',),
#  ('Ivanovo',),
#  ('Ogbomosho',),
#  ('Izumisano',),
#  ('Ikerre',),
#  ('Idfu',),
#  ('Akishima',),
#  ('Adana',),
#  ('Abha',),
#  ('Ezhou',),
#  ('Udine',),
#  ('Amroha',),
#  ('Oulu',),
#  ('El Monte',),
#  ('El Fuerte',),
#  ('Addis Abeba',),
#  ('Allende',),
#  ('Avellaneda',),
#  ('Arecibo',),
#  ('Ueda',),
#  ('Abu Dhabi',),
#  ('Enshi',),
#  ('Aurora',),
#  ('Antofagasta',),
#  ('Usolje-Sibirskoje',),
#  ('Acua',),
#  ('Urawa',),
#  ('Iwaki',),
#  ('al-Manama',),
#  ('Owo',),
#  ('Alvorada',),
#  ('Onomichi',),
#  ('Ife',),
#  ('Adoni',),
#  ('Iwatsuki',),
#  ('Oyo',),
#  ('Isesaki',),
#  ('Ezeiza',),
#  ('Ede',),
#  ('ostka',),
#  ('Oshawa',),
#  ('Athenai',),
#  ('Omiya',),
#  ('El Alto',),
#  ('Otsu',),
#  ('Uijongbu',),
#  ('Okayama',)]

# %% [markdown]
# 26. Write a query to get the first_name from the actor table in the upper case using the alias name as ActorName.

# %%
# %%sql
#     select upper(first_name) as actor_name
#     from actor
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 200 rows affected.
# [('PENELOPE',),
#  ('NICK',),
#  ('ED',),
#  ('JENNIFER',),
#  ('JOHNNY',),
#  ('BETTE',),
#  ('GRACE',),
#  ('MATTHEW',),
#  ('JOE',),
#  ('CHRISTIAN',),
#  ('ZERO',),
#  ('KARL',),
#  ('UMA',),
#  ('VIVIEN',),
#  ('CUBA',),
#  ('FRED',),
#  ('HELEN',),
#  ('DAN',),
#  ('BOB',),
#  ('LUCILLE',),
#  ('KIRSTEN',),
#  ('ELVIS',),
#  ('SANDRA',),
#  ('CAMERON',),
#  ('KEVIN',),
#  ('RIP',),
#  ('JULIA',),
#  ('WOODY',),
#  ('ALEC',),
#  ('SANDRA',),
#  ('SISSY',),
#  ('TIM',),
#  ('MILLA',),
#  ('AUDREY',),
#  ('JUDY',),
#  ('BURT',),
#  ('VAL',),
#  ('TOM',),
#  ('GOLDIE',),
#  ('JOHNNY',),
#  ('JODIE',),
#  ('TOM',),
#  ('KIRK',),
#  ('NICK',),
#  ('REESE',),
#  ('PARKER',),
#  ('JULIA',),
#  ('FRANCES',),
#  ('ANNE',),
#  ('NATALIE',),
#  ('GARY',),
#  ('CARMEN',),
#  ('MENA',),
#  ('PENELOPE',),
#  ('FAY',),
#  ('DAN',),
#  ('JUDE',),
#  ('CHRISTIAN',),
#  ('DUSTIN',),
#  ('HENRY',),
#  ('CHRISTIAN',),
#  ('JAYNE',),
#  ('CAMERON',),
#  ('RAY',),
#  ('ANGELA',),
#  ('MARY',),
#  ('JESSICA',),
#  ('RIP',),
#  ('KENNETH',),
#  ('MICHELLE',),
#  ('ADAM',),
#  ('SEAN',),
#  ('GARY',),
#  ('MILLA',),
#  ('BURT',),
#  ('ANGELINA',),
#  ('CARY',),
#  ('GROUCHO',),
#  ('MAE',),
#  ('RALPH',),
#  ('SCARLETT',),
#  ('WOODY',),
#  ('BEN',),
#  ('JAMES',),
#  ('MINNIE',),
#  ('RIVER',),
#  ('GREG',),
#  ('SPENCER',),
#  ('KENNETH',),
#  ('CHARLIZE',),
#  ('SEAN',),
#  ('CHRISTOPHER',),
#  ('KIRSTEN',),
#  ('ELLEN',),
#  ('KENNETH',),
#  ('DARYL',),
#  ('GENE',),
#  ('MEG',),
#  ('CHRIS',),
#  ('JIM',),
#  ('SPENCER',),
#  ('SUSAN',),
#  ('WALTER',),
#  ('MATTHEW',),
#  ('PENELOPE',),
#  ('SIDNEY',),
#  ('GROUCHO',),
#  ('GINA',),
#  ('WARREN',),
#  ('SYLVESTER',),
#  ('SUSAN',),
#  ('CAMERON',),
#  ('RUSSELL',),
#  ('MORGAN',),
#  ('MORGAN',),
#  ('HARRISON',),
#  ('DAN',),
#  ('RENEE',),
#  ('CUBA',),
#  ('WARREN',),
#  ('PENELOPE',),
#  ('LIZA',),
#  ('SALMA',),
#  ('JULIANNE',),
#  ('SCARLETT',),
#  ('ALBERT',),
#  ('FRANCES',),
#  ('KEVIN',),
#  ('CATE',),
#  ('DARYL',),
#  ('GRETA',),
#  ('JANE',),
#  ('ADAM',),
#  ('RICHARD',),
#  ('GENE',),
#  ('RITA',),
#  ('ED',),
#  ('MORGAN',),
#  ('LUCILLE',),
#  ('EWAN',),
#  ('WHOOPI',),
#  ('CATE',),
#  ('JADA',),
#  ('ANGELA',),
#  ('KIM',),
#  ('ALBERT',),
#  ('FAY',),
#  ('EMILY',),
#  ('RUSSELL',),
#  ('JAYNE',),
#  ('GEOFFREY',),
#  ('BEN',),
#  ('MINNIE',),
#  ('MERYL',),
#  ('IAN',),
#  ('FAY',),
#  ('GRETA',),
#  ('VIVIEN',),
#  ('LAURA',),
#  ('CHRIS',),
#  ('HARVEY',),
#  ('OPRAH',),
#  ('CHRISTOPHER',),
#  ('HUMPHREY',),
#  ('AL',),
#  ('NICK',),
#  ('LAURENCE',),
#  ('WILL',),
#  ('KENNETH',),
#  ('MENA',),
#  ('OLYMPIA',),
#  ('GROUCHO',),
#  ('ALAN',),
#  ('MICHAEL',),
#  ('WILLIAM',),
#  ('JON',),
#  ('GENE',),
#  ('LISA',),
#  ('ED',),
#  ('JEFF',),
#  ('MATTHEW',),
#  ('DEBBIE',),
#  ('RUSSELL',),
#  ('HUMPHREY',),
#  ('MICHAEL',),
#  ('JULIA',),
#  ('RENEE',),
#  ('ROCK',),
#  ('CUBA',),
#  ('AUDREY',),
#  ('GREGORY',),
#  ('JOHN',),
#  ('BURT',),
#  ('MERYL',),
#  ('JAYNE',),
#  ('BELA',),
#  ('REESE',),
#  ('MARY',),
#  ('JULIA',),
#  ('THORA',)]

# %% [markdown]
# 27. Write a query to fetch the current date?

# %%
# %%sql
#     select current_date
# Out:
#  * postgresql://postgres:***@localhost/DVDRental
#    postgresql://postgres:***@localhost/NorthWind
# 1 rows affected.
# [(datetime.date(2022, 2, 26),)]
